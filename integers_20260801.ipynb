# %%
a = 90
y = 20.3
vaibhav = "my name is vaibhav"

print(x)
print(y)
print(vaibhav)

print(type(x))
print(type(y))
print(type(vaibhav))
# Out:
# 90
# 20.3
# my name is vaibhav
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
int,float,str

# %%
a = 200
e = 20.4
name = "Edukron"

# %%
print(a)
print(e)
print(name)
# Out:
# 200
# 20.4
# Edukron

# %%
TYPES OF VARIABLES:

# %%
print(type(a))
print(type(e))
print(type(name))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
int,float,str

# %%
z = 29
print(z)
print(type(z))
# Out:
# 29
# <class 'int'>

# %%
c = 30
print(c)
print(type(c))
# Out:
# 30
# <class 'int'>

# %%
mishra = "MY NAME IS VAIBHAV CHANDRA MISHRA"
print(mishra)
print(type(mishra))
# Out:
# MY NAME IS VAIBHAV CHANDRA MISHRA
# <class 'str'>

# %%
Complex number:

# %%
a = 2+3j
print(a)
print(type(a))
# Out:
# (2+3j)
# <class 'complex'>

# %%
To find imaginary and real number in complex:

# %%
a.real
print(a)
# Out:
# (2+3j)

# %%
a =2+3j
a.real
# Out:
# 2.0

# %%
a = 2+3j
a.imag
# Out:
# 3.0

# %%
INDEXING:

# %%
vaibhav = "Edukron Data Science and Data Engineering Batch 2026"
print(vaibhav)
# Out:
# Edukron Data Science and Data Engineering Batch 2026

# %%
vaibhav[0:7]
# Out:
# 'Edukron'

# %%
vaibhav[8:12]
vaibhav[-45:-40]
# Out:
# ' Data'

# %%
vaibhav[13:20]
vaibhav[-39:-32]
# Out:
# 'Science'

# %%
vaibhav[20:24]
vaibhav[-32:-27]
# Out:
# ' and '

# %%
vaibhav[25:42]
vaibhav[-28:-10]
# Out:
# ' Data Engineering '

# %%
vaibhav[30:42]
vaibhav[-22:-10]
# Out:
# 'Engineering '

# %%
vaibhav[42:47]
vaibhav[-11:-5]
# Out:
# ' Batch'

# %%
vaibhav[48:57]
# Out:
# '2026'

# %%
vaibhav[13:30]
vaibhav[-39:-22]
# Out:
# 'Science and Data '

# %%
vaibhav[7:47]
vaibhav[-45:-5]
# Out:
# ' Data Science and Data Engineering Batch'
