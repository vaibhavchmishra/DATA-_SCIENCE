# %%
#INDEXING:

# %%
vaibhav = "Edukron Data Science and Data Engineering Batch 2026"
print(vaibhav)
# Out:
# Edukron Data Science and Data Engineering Batch 2026

# %%
#print - Edukron Data Science and Data Engineering Batch 2026

# %%
vaibhav[0:7]
# Out:
# 'Edukron'

# %%
vaibhav[8:12]
vaibhav[-45:-40]
# Out:
# ' Data'

# %%
vaibhav[13:20]
vaibhav[-39:-32]
# Out:
# 'Science'

# %%
vaibhav[20:24]
vaibhav[-32:-27]
# Out:
# ' and '

# %%
vaibhav[25:42]
vaibhav[-28:-10]
# Out:
# ' Data Engineering '

# %%
vaibhav[30:42]
vaibhav[-22:-10]
# Out:
# 'Engineering '

# %%
vaibhav[42:47]
vaibhav[-11:-5]
# Out:
# ' Batch'

# %%
vaibhav[48:57]
# Out:
# '2026'

# %%
vaibhav[13:30]
vaibhav[-39:-22]
# Out:
# 'Science and Data '

# %%
vaibhav[7:47]
vaibhav[-45:-5]
# Out:
# ' Data Science and Data Engineering Batch'
